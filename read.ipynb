# %%
import pandas as pd

# %%
# df1 = pd.read_csv('data/my_data/viral.1.genomic_cds_file.csv')
# df2 = pd.read_csv('data/my_data/viral.1.genomic_gene_file.csv')
# df3 = pd.read_csv('data/my_data/viral.1.genomic_no_cds_gene.csv')
# df4 = pd.read_csv('data/fine-tune/BPDR.250bp.train.paired.csv')
# df5 = pd.read_csv('data/SARS-CoV-2/SRR14403295.paired.csv')
df6 = pd.read_csv('data/my_data/viral.1.1.genomic.fna.csv')
df6
for i in range(0,len(df6)):
    print(len(df6.loc[i][0]))
# Out:
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# 1239
# ...
